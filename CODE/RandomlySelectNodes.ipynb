# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv(r'../PreparedData/Y_time/good/Weekday/NodeLists/Test_list.csv')

# %%
df_train = df_train.drop(columns=['Unnamed: 0'])
values = df_train.values

# %%
values
# Out:
# array([[560, '2016_1_4.csv'],
#        [1132, '2016_1_4.csv'],
#        [1146, '2016_1_4.csv'],
#        ...,
#        [13483, '2019_10_16.csv'],
#        [13540, '2019_10_16.csv'],
#        [14123, '2019_10_16.csv']], dtype=object)

# %%
np.random.shuffle(values)

# %%
values[0:500]
# Out:
# array([[4692, '2019_10_10.csv'],
#        [9156, '2018_10_15.csv'],
#        [17332, '2016_11_17.csv'],
#        [9755, '2018_11_6.csv'],
#        [14219, '2017_12_6.csv'],
#        [13399, '2017_12_4.csv'],
#        [4014, '2018_11_6.csv'],
#        [7711, '2016_3_22.csv'],
#        [17060, '2016_3_23.csv'],
#        [16942, '2016_10_21.csv'],
#        [4485, '2016_2_29.csv'],
#        [12225, '2016_11_17.csv'],
#        [16941, '2018_10_15.csv'],
#        [16941, '2018_10_16.csv'],
#        [4536, '2018_10_16.csv'],
#        [11935, '2016_11_1.csv'],
#        [15789, '2019_6_14.csv'],
#        [13531, '2016_10_17.csv'],
#        [4933, '2018_10_15.csv'],
#        [5326, '2016_10_21.csv'],
#        [11207, '2016_3_4.csv'],
#        [3045, '2017_11_9.csv'],
#        [6101, '2017_3_2.csv'],
#        [9775, '2019_10_10.csv'],
#        [3760, '2019_11_22.csv'],
#        [9330, '2018_10_15.csv'],
#        [4649, '2016_10_19.csv'],
#        [13553, '2018_1_17.csv'],
# ...

# %%
df = pd.DataFrame(values[0:500], columns=['node', 'time'])

# %%
df.to_csv(r'../PreparedData/Y_time/good/Weekday/Test_list1.csv')
